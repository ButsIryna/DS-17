# %%
##Для трьох введених натуральних чисел (користувач вводить числа через пробіл) знайдіть мінімальне та максимальне

##numbers = input()

a,b,c=map(int,input().split())

j=[a,b,c]

max = j[0]
min = j[0]

for i in range(0,len(j)):
    if j[i]<min:
        min=j[i]
    if j[i]>max:
        max=j[i]

print('min =', min)
print('max =', max)
# Out:
#  2 5 8
# min = 2
# max = 8

# %%
#Програма приймає на вхід два параметри: стать спортсмена(`sex = (f, m)`) та вік спортсмена(`age = [0,100]`). 
#Спортсмен-дівчина може брати участь у змаганні, якщо її вік більший 18, спортсмен-хлопець - якщо вік більший 16
#Якщо введені не коректні дані, виведіть повідомлення про помилку

a, b = ('female', 'male')
c = ([0,100])
    
sex = input("Вкажіть свою стать (female / male):")
age = float(input("Вкажіть свій вік:"))

if sex == 'female':
    if age > 18:
        print("Ви приймаєте участь у змаганні")

    elif sex == 'female':
        if age < 18:
            print("Ви не можете приймати участь у змаганні")
        
if sex == 'male':
    if age > 16:
            print("Ви приймаєте участь у змаганні")
            
    elif sex == 'male':
        if age < 16:
            print("Ви не можете приймати участь у змаганні")    
        
else:
    print("Ви ввели не коректні дані")
# Out:
# Вкажіть свою стать (female / male): male
# Вкажіть свій вік: 25
# Ви приймаєте участь у змаганні

# %%
#Для введеного натурального числа побудуйте драбинку. 
#Наприклад, якщо N = 5, драбинка буде мати вигляд:
#&
#&&
#&&&
#&&&&
#&&&&&


N = int(input())

while N < 1000000:
    print(N)
    N = N*10
# Out:
#  5
# 5
# 50
# 500
# 5000
# 50000
# 500000

# %%
#Із заданого речення виведіть кожне слово і його довжину

#sentence = 'My favourite tutor in academy is Ihor'

s = "My favourite tutor in academy is Ihor"
lst = s.split()
print(lst)

print(list(zip(lst,map(lambda x: len(str(x)), lst))))
# Out:
# ['My', 'favourite', 'tutor', 'in', 'academy', 'is', 'Ihor']
# [('My', 2), ('favourite', 9), ('tutor', 5), ('in', 2), ('academy', 7), ('is', 2), ('Ihor', 4)]

# %%
#Для заданого тексту реалізуйте:
#* Знайдіть кількість слів
#* Знайдіть кількість унікальних слів
#* Своірть словник, де ключе буде слово із тексту, значенням - частота зустрічання в тексті
#* Виведіть топ-3 слів, що найчастіше зустрічаються

#Вважаємо, що слово це стрічка з трьох і більше букв, очищена від знаків пунктуації

# %%
text = """До чого ж гарно і весело було в нашому горóді! Ото як вийти з сіней та подивись навколо — геть-чисто все зелене та буйне. А сад було як зацвіте весною! А що робилось на початку літа — огірки цвітуть, гарбузи цвітуть, картопля цвіте. Цвіте малина, смородина, тютюн, квасоля. А соняшника, а маку, буряків, лободи, укропу, моркви! Чого тільки не насадить наша невгамовна мати.

— Нічого в світі так я не люблю, як саджати що-небудь у землю, щоб проізростало. Коли вилізає з землі всяка рослиночка, ото мені радість,— любила проказувати вона.

Город до того переповнявсь рослинами, що десь серед літа вони вже не вміщалися в ньому. Вони лізли одна на одну, переплітались, душились, дерлися на хлів, на стріху, повзли на тин, а гарбузи звисали з тину прямо на вулицю.

Дід любив кашляти. Кашляв він часом так довго й гучно, що скільки ми не старалися, ніхто не міг його як слід передражнити. Його кашель чув увесь куток. Старі люди по дідовому кашлю вгадували навіть погоду."""


import string

if __name__ == '__main__':
 
    s = text
    s = s.translate(str.maketrans('', '', string.punctuation)) #убрала пунктуацию

text_string = s.lower() #убрала большие буквы

newtext = ' '.join([word for word in text_string.split(' ') if len(word) >= 3]) #новый текст с символами не более 3

lst = newtext.split() #разбила текст на слова по пробелам

a = list(zip(lst,map(lambda x: len(str(x)), lst))) 
print("Довжина слова:", a) #посчитала длину каждого слова

print("Кількість слів = ", len(lst)) #посчитала кол-во слов

unic = []
for j in lst:
    if j not  in unic:
        unic.append(j)
print("Кількість унікальних слів = ", len(unic)) #посчитала кол-во уникальных слов


frequency = {}
for word in lst:
    count = frequency.get(word,0)
    frequency[word] = count + 1
frequency_list = frequency.keys()
print("Частота слова:", frequency) #посчитала частоту слов

#вывести 3 наиболее частые
word_count = {}
for word in lst:
    if len(word) >= 3:
        if word in word_count:
           word_count[word] += 1
        else:
            word_count[word] = 1

sorted_word_count = sorted(word_count.items(), key=lambda х: х[1], reverse=True)

top_words = [word for word, count in sorted_word_count[:3]]
print ("top_3_words:", top_words)
    
sorted_pairs = {}
for sorted_pairs in sorted(frequency.items(), key=lambda pair: (pair[1], pair[0]), reverse=True):
    print ("sorted_pairs", sorted_pairs)
# Out:
# Довжина слова: [('чого', 4), ('гарно', 5), ('весело', 6), ('було', 4), ('нашому', 6), ('горóді', 6), ('ото', 3), ('вийти', 5), ('сіней', 5), ('подивись', 8), ('навколо', 7), ('гетьчисто', 9), ('все', 3), ('зелене', 6), ('буйне', 5), ('сад', 3), ('було', 4), ('зацвіте', 7), ('весною', 6), ('робилось', 8), ('початку', 7), ('літа', 4), ('огірки', 6), ('цвітуть', 7), ('гарбузи', 7), ('цвітуть', 7), ('картопля', 8), ('цвіте', 5), ('цвіте', 5), ('малина', 6), ('смородина', 9), ('тютюн', 5), ('квасоля', 7), ('соняшника', 9), ('маку', 4), ('буряків', 7), ('лободи', 6), ('укропу', 6), ('моркви', 6), ('чого', 4), ('тільки', 6), ('насадить', 8), ('наша', 4), ('невгамовна', 10), ('мати', 4), ('—', 1), ('нічого', 6), ('світі', 5), ('так', 3), ('люблю', 5), ('саджати', 7), ('щонебудь', 8), ('землю', 5), ('щоб', 3), ('проізростало', 12), ('коли', 4), ('вилізає', 7), ('землі', 5), ('всяка', 5), ('рослиночка', 10), ('ото', 3), ('мені', 4), ('радість—', 8), ('любила', 6), ('проказувати', 11), ('вона', 4), ('город', 5), ('того', 4), ('переповнявсь', 12), ('рослинами', 9), ('десь', 4), ('серед', 5), ('літа', 4), ('вони', 4), ('вже', 3), ('вміщалися', 9), ('ньому', 5), ('вони', 4), ('лізли', 5), ('одна', 4), ('одну', 4), ('переплітались', 13), ('душились', 8), ('дерлися', 7), ('хлів', 4), ('стріху', 6), ('повзли', 6), ('тин', 3), ('гарбузи', 7), ('звисали', 7), ('тину', 4), ('прямо', 5), ('вулицю', 6), ('а', 1), ('малини', 6), ('красної', 7), ('білої', 5), ('вишень', 6), ('груш', 4), ('солодких', 8), ('було', 4), ('наїсися—', 8), ('цілий', 5), ('день', 4), ('живіт', 5), ('бубон', 5), ('і', 1), ('росло', 5), ('пригадую', 8), ('багато', 6), ('тютюну', 6), ('якому', 5), ('маленькі', 8), ('ходили', 6), ('мов', 3), ('лісі', 4), ('якому', 5), ('пізнали', 7), ('перші', 5), ('мозолі', 6), ('дитячих', 7), ('руках', 5), ('а', 1), ('вздовж', 6), ('тину', 4), ('старою', 6), ('повіткою', 8), ('росли', 5), ('великі', 6), ('кущі', 4), ('смородини', 9), ('бузини', 6), ('якихось', 7), ('невідомих', 9), ('рослин', 6), ('там', 3), ('неслися', 7), ('кури', 4), ('нишком', 6), ('матері', 6), ('різне', 5), ('дрібне', 6), ('птаство', 7), ('туди', 4), ('рідко', 5), ('лазили', 6), ('там', 3), ('було', 4), ('темно', 5), ('навіть', 6), ('удень', 5), ('боялись', 7), ('гадюки', 6), ('хто', 3), ('нас', 3), ('дитинстві', 9), ('боявся', 6), ('гадюки', 6), ('так', 3), ('все', 3), ('життя', 5), ('побачивши', 9), ('ніде', 4), ('коло', 4), ('хати', 4), ('стояла', 6), ('саду', 4), ('цвіли', 5), ('квіти', 5), ('хатою', 5), ('проти', 5), ('сінешніх', 8), ('дверей', 6), ('коло', 4), ('вишень—', 7), ('поросла', 7), ('полином', 7), ('стара', 5), ('погребня', 8), ('одкритою', 8), ('лядою', 5), ('звідки', 6), ('завжди', 6), ('пахло', 5), ('цвіллю', 6), ('там', 3), ('льоху', 5), ('присмерку', 9), ('плигали', 7), ('жаби', 4), ('напевно', 7), ('там', 3), ('водилися', 8), ('гадюки', 6), ('на', 2), ('погребні', 8), ('любив', 5), ('спати', 5), ('дід', 3), ('у', 1), ('нас', 3), ('був', 3), ('дід', 3), ('дуже', 4), ('схожий', 6), ('бога', 4), ('коли', 4), ('молився', 7), ('богу', 4), ('завжди', 6), ('бачив', 5), ('покуті', 6), ('портрет', 7), ('діда', 4), ('старих', 6), ('срібнофольгових', 15), ('шатах', 5), ('сам', 3), ('дід', 3), ('лежав', 5), ('печі', 4), ('тихо', 4), ('кашляв', 6), ('слухаючи', 8), ('своїх', 5), ('молитов', 7), ('у', 1), ('неділю', 6), ('перед', 5), ('богами', 6), ('горіла', 6), ('маленька', 8), ('синенька', 8), ('лампадка', 8), ('яку', 3), ('завжди', 6), ('набиралось', 10), ('повно', 5), ('мух', 3), ('образ', 5), ('святого', 7), ('миколая', 7), ('також', 5), ('був', 3), ('схожий', 6), ('діда', 4), ('особливо', 8), ('коли', 4), ('дід', 3), ('часом', 5), ('підстригав', 10), ('собі', 4), ('бороду', 6), ('випивав', 7), ('перед', 5), ('обідом', 6), ('чарку', 5), ('горілки', 7), ('перцем', 6), ('мати', 4), ('лаялась', 7), ('святий', 6), ('федосій', 7), ('більш', 5), ('скидався', 8), ('батька', 6), ('федосію', 7), ('молився', 7), ('нього', 5), ('була', 4), ('темна', 5), ('борода', 6), ...
# sorted_pairs ('—', 4)
# sorted_pairs ('часом', 4)
# sorted_pairs ('там', 4)
# sorted_pairs ('так', 4)
# sorted_pairs ('прямо', 4)
# sorted_pairs ('нього', 4)
# sorted_pairs ('нас', 4)
# sorted_pairs ('мати', 4)
# sorted_pairs ('коло', 4)
# sorted_pairs ('завжди', 4)
# sorted_pairs ('вона', 4)
# sorted_pairs ('було', 4)
# sorted_pairs ('чого', 3)
# sorted_pairs ('хто', 3)
# sorted_pairs ('схожий', 3)
# sorted_pairs ('псалтир', 3)
# sorted_pairs ('печі', 3)
# sorted_pairs ('гадюки', 3)
# sorted_pairs ('все', 3)
# sorted_pairs ('бог', 3)
# sorted_pairs ('якому', 2)
# sorted_pairs ('щоб', 2)
# sorted_pairs ('цвітуть', 2)
# sorted_pairs ('цвіте', 2)
# sorted_pairs ('у', 2)
# sorted_pairs ('тину', 2)
# sorted_pairs ('старою', 2)
# sorted_pairs ('стара', 2)
# sorted_pairs ('сонцем', 2)
# sorted_pairs ('світі', 2)
# sorted_pairs ('руці', 2)
# sorted_pairs ('росло', 2)
# sorted_pairs ('під', 2)
# sorted_pairs ('погребні', 2)
# sorted_pairs ('перед', 2)
# sorted_pairs ('ото', 2)
# sorted_pairs ('неділю', 2)
# sorted_pairs ('навіть', 2)
# sorted_pairs ('навколо', 2)
# sorted_pairs ('молився', 2)
# sorted_pairs ('матері', 2)
# sorted_pairs ('літа', 2)
# sorted_pairs ('літ', 2)
# sorted_pairs ('лісі', 2)
# sorted_pairs ('людина', 2)
# sorted_pairs ('кашляв', 2)
# sorted_pairs ('звідки', 2)
# sorted_pairs ('довго', 2)
# sorted_pairs ('гарбузи', 2)
# sorted_pairs ('вони', 2)
# sorted_pairs ('вже', 2)
# sorted_pairs ('більш', 2)
# sorted_pairs ('була', 2)
# sorted_pairs ('борода', 2)
# sorted_pairs ('а', 2)
# sorted_pairs ('і', 1)
# sorted_pairs ('яку', 1)
# sorted_pairs ('якихось', 1)
# sorted_pairs ('ягоди', 1)
# sorted_pairs ('яблуні', 1)
# sorted_pairs ('щонебудь', 1)
# sorted_pairs ('шляху', 1)
# sorted_pairs ('шкіряна', 1)
# sorted_pairs ('шатах', 1)
# sorted_pairs ('чумацьких', 1)
# sorted_pairs ('чув', 1)
# sorted_pairs ('чорнокнижника', 1)
# sorted_pairs ('чорний', 1)
# sorted_pairs ('чомусь', 1)
# sorted_pairs ('чоло', 1)
# sorted_pairs ('читати', 1)
# sorted_pairs ('часнику', 1)
# sorted_pairs ('час', 1)
# sorted_pairs ('чарку', 1)
# sorted_pairs ('цілий', 1)
# sorted_pairs ('цвіллю', 1)
# sorted_pairs ('цвіли', 1)
# sorted_pairs ('хіба', 1)
# sorted_pairs ('хустку', 1)
# sorted_pairs ('худий', 1)
# sorted_pairs ('холодок', 1)
# sorted_pairs ('ходили', 1)
# sorted_pairs ('ховаючись', 1)
# sorted_pairs ('хлів', 1)
# sorted_pairs ('хвилясте', 1)
# sorted_pairs ('хвилювало', 1)
# sorted_pairs ('хатою', 1)
# sorted_pairs ('хати', 1)
# sorted_pairs ('халява', 1)
# sorted_pairs ('федосію', 1)
# sorted_pairs ('федосій', 1)
# sorted_pairs ('усіх', 1)
# sorted_pairs ('усім', 1)
# sorted_pairs ('услід', 1)
# sorted_pairs ('урочисто', 1)
# sorted_pairs ('укропу', 1)
# sorted_pairs ('укопаний', 1)
# sorted_pairs ('удень', 1)
# sorted_pairs ('увесь', 1)
# sorted_pairs ('тільки', 1)
# sorted_pairs ('тютюну', 1)
# sorted_pairs ('тютюн', 1)
# sorted_pairs ('туди', 1)
# sorted_pairs ('трьома', 1)
# sorted_pairs ('трохи', 1)
# sorted_pairs ('трогайбо', 1)
# sorted_pairs ('тримав', 1)
# sorted_pairs ('травами', 1)
# sorted_pairs ('той', 1)
# sorted_pairs ('того', 1)
# sorted_pairs ('товста', 1)
# sorted_pairs ('тихо', 1)
# sorted_pairs ('тин', 1)
# sorted_pairs ('теплою', 1)
# sorted_pairs ('темно', 1)
# sorted_pairs ('темна', 1)
# sorted_pairs ('телятами', 1)
# sorted_pairs ('таємниця', 1)
# sorted_pairs ('також', 1)
# sorted_pairs ('таки', 1)
# sorted_pairs ('сінешніх', 1)
# sorted_pairs ('сіней', 1)
# sorted_pairs ('сільничку', 1)
# sorted_pairs ('сідаючи', 1)
# sorted_pairs ('стріху', 1)
# sorted_pairs ('стоїш', 1)
# sorted_pairs ('стояла', 1)
# sorted_pairs ('стояв', 1)
# sorted_pairs ('старі', 1)
# sorted_pairs ('старих', 1)
# sorted_pairs ('старалися', 1)
# sorted_pairs ('ста', 1)
# sorted_pairs ('срібнофольгових', 1)
# sorted_pairs ('спати', 1)
# sorted_pairs ('спалила', 1)
# sorted_pairs ('соняшника', 1)
# sorted_pairs ('сонце', 1)
# sorted_pairs ('солодких', 1)
# sorted_pairs ('собі', 1)
# sorted_pairs ('смородини', 1)
# sorted_pairs ('смородина', 1)
# sorted_pairs ('смислу', 1)
# sorted_pairs ('слід', 1)
# sorted_pairs ('слухаючи', 1)
# sorted_pairs ('слово', 1)
# sorted_pairs ('скільки', 1)
# sorted_pairs ('скидався', 1)
# sorted_pairs ('синенька', 1)
# sorted_pairs ('сиве', 1)
# sorted_pairs ('серед', 1)
# sorted_pairs ('семеном', 1)
# sorted_pairs ('святого', 1)
# sorted_pairs ('святий', 1)
# sorted_pairs ('своїх', 1)
# sorted_pairs ('сам', 1)
# sorted_pairs ('саду', 1)
# sorted_pairs ('саджати', 1)
# sorted_pairs ('сад', 1)
# sorted_pairs ('різне', 1)
# sorted_pairs ('рідко', 1)
# sorted_pairs ('рухалось', 1)
# sorted_pairs ('руках', 1)
# sorted_pairs ('рослиночка', 1)
# sorted_pairs ('рослинами', 1)
# sorted_pairs ('рослин', 1)
# sorted_pairs ('росли', 1)
# sorted_pairs ('розуміли', 1)
# sorted_pairs ('розніс', 1)
# sorted_pairs ('розмовляв', 1)
# sorted_pairs ('робилось', 1)
# sorted_pairs ('риби', 1)
# sorted_pairs ('радість—', 1)
# sorted_pairs ('пізнали', 1)
# sorted_pairs ('підстригав', 1)
# sorted_pairs ('пужалном', 1)
# sorted_pairs ('птаство', 1)
# sorted_pairs ('проізростало', 1)
# sorted_pairs ('прочитаному', 1)
# sorted_pairs ('прочитаного', 1)
# sorted_pairs ('проти', 1)
# sorted_pairs ('проказувати', 1)
# sorted_pairs ('прожив', 1)
# sorted_pairs ('присмерку', 1)
# sorted_pairs ('прийшов', 1)
# sorted_pairs ('пригадую', 1)
# sorted_pairs ('поїхала', 1)
# sorted_pairs ('початку', 1)
# sorted_pairs ('поцерковному', 1)
# sorted_pairs ('потім', 1)
# sorted_pairs ('посеред', 1)
# sorted_pairs ('портрет', 1)
# sorted_pairs ('поросла', 1)
# sorted_pairs ('помер', 1)
# sorted_pairs ('полином', 1)
# sorted_pairs ('покуті', 1)
# sorted_pairs ('подорожній', 1)
# sorted_pairs ('подорожньому', 1)
# sorted_pairs ('подивись', 1)
# sorted_pairs ('погребня', 1)
# sorted_pairs ('погоду', 1)
# sorted_pairs ('повіткою', 1)
# sorted_pairs ('повно', 1)
# sorted_pairs ('повзли', 1)
# sorted_pairs ('побачивши', 1)
# sorted_pairs ('плигали', 1)
# sorted_pairs ('питав', 1)
# sorted_pairs ('письменний', 1)
# sorted_pairs ('перші', 1)
# sorted_pairs ('перцем', 1)
# sorted_pairs ('переповнявсь', 1)
# sorted_pairs ('переплітались', 1)
# sorted_pairs ('передражнити', 1)
# sorted_pairs ('пахнув', 1)
# sorted_pairs ('пахло', 1)
# sorted_pairs ('палітурка', 1)
# sorted_pairs ('палити', 1)
# sorted_pairs ('пýчками', 1)
# sorted_pairs ('ота', 1)
# sorted_pairs ('особливого', 1)
# sorted_pairs ('особливо', 1)
# sorted_pairs ('одягнена', 1)
# sorted_pairs ('одній', 1)
# sorted_pairs ('одну', 1)
# sorted_pairs ('одному', 1)
# sorted_pairs ('одна', 1)
# sorted_pairs ('одкритою', 1)
# sorted_pairs ('огірки', 1)
# sorted_pairs ('обідом', 1)
# sorted_pairs ('образ', 1)
# sorted_pairs ('нічого', 1)
# sorted_pairs ('ніхто', 1)
# sorted_pairs ('нікуди', 1)
# sorted_pairs ('ніколи', 1)
# sorted_pairs ('ніде', 1)
# sorted_pairs ('ньому', 1)
# sorted_pairs ('ну', 1)
# sorted_pairs ('нишком', 1)
# sorted_pairs ('неслися', 1)
# sorted_pairs ('неначе', 1)
# sorted_pairs ('ненавиділа', 1)
# sorted_pairs ('невідомих', 1)
# sorted_pairs ('невгамовна', 1)
# sorted_pairs ('небуденного', 1)
# sorted_pairs ('наїсися—', 1)
# sorted_pairs ('нашому', 1)
# sorted_pairs ('нашого', 1)
# sorted_pairs ('наша', 1)
# sorted_pairs ('наш', 1)
# sorted_pairs ('насадить', 1)
# sorted_pairs ('нарешті', 1)
# sorted_pairs ('напевно', 1)
# sorted_pairs ('нападів', 1)
# sorted_pairs ('надавала', 1)
# sorted_pairs ('набиралось', 1)
# sorted_pairs ('на', 1)
# sorted_pairs ('міг', 1)
# sorted_pairs ('мух', 1)
# sorted_pairs ('моркви', 1)
# sorted_pairs ('молодих', 1)
# sorted_pairs ('молитов', 1)
# sorted_pairs ('мозолі', 1)
# sorted_pairs ('мов', 1)
# sorted_pairs ('млином', 1)
# sorted_pairs ('миколая', 1)
# sorted_pairs ('мені', 1)
# sorted_pairs ('мед', 1)
# sorted_pairs ('махаючи', 1)
# sorted_pairs ('малини', 1)
# sorted_pairs ('малина', 1)
# sorted_pairs ('маленькі', 1)
# sorted_pairs ('маленька', 1)
# sorted_pairs ('маку', 1)
# sorted_pairs ('лізли', 1)
# sorted_pairs ('лядою', 1)
# sorted_pairs ('люди', 1)
# sorted_pairs ('люблю', 1)
# sorted_pairs ('любила', 1)
# sorted_pairs ('льоху', 1)
# sorted_pairs ('лугу', 1)
# sorted_pairs ('луг', 1)
# sorted_pairs ('лободи', 1)
# sorted_pairs ('листочку', 1)
# sorted_pairs ('лежав', 1)
# sorted_pairs ('лаялась', 1)
# sorted_pairs ('лампадка', 1)
# sorted_pairs ('лазили', 1)
# sorted_pairs ('лагідно', 1)
# sorted_pairs ('кіньми', 1)
# sorted_pairs ('кущі', 1)
# sorted_pairs ('кущах', 1)
# sorted_pairs ('куток', 1)
# sorted_pairs ('кури', 1)
# sorted_pairs ('круглу', 1)
# sorted_pairs ('краще', 1)
# sorted_pairs ('красної', 1)
# sorted_pairs ('крадькома', 1)
# sorted_pairs ('коричнева', 1)
# sorted_pairs ('коня', 1)
# sorted_pairs ('квіти', 1)
# sorted_pairs ('квасоля', 1)
# sorted_pairs ('кашляти', 1)
# sorted_pairs ('кашлю', 1)
# sorted_pairs ('кашель', 1)
# sorted_pairs ('картопля', 1)
# sorted_pairs ('зітхав', 1)
# sorted_pairs ('зубок', 1)
# sorted_pairs ('зрештою', 1)
# sorted_pairs ('зразу', 1)
# sorted_pairs ('знищила', 1)
# sorted_pairs ('зникав', 1)
# sorted_pairs ('знає', 1)
# sorted_pairs ('знаю', 1)
# sorted_pairs ('землі', 1)
# sorted_pairs ('землю', 1)
# sorted_pairs ('землею', 1)
# sorted_pairs ('зелене', 1)
# sorted_pairs ('здоровя—', 1)
# sorted_pairs ('звисали', 1)
# sorted_pairs ('звертайте', 1)
# sorted_pairs ('звертався', 1)
# sorted_pairs ('звали', 1)
# sorted_pairs ('збирався', 1)
# sorted_pairs ('збирав', 1)
# sorted_pairs ('зацвіте', 1)
# sorted_pairs ('захищали', 1)
# sorted_pairs ('життя', 1)
# sorted_pairs ('живіт', 1)
# sorted_pairs ('живим', 1)
# sorted_pairs ('жаби', 1)
# sorted_pairs ('діду', 1)
# sorted_pairs ('дідовому', 1)
# sorted_pairs ('душились', 1)
# sorted_pairs ('дух', 1)
# sorted_pairs ('дуже', 1)
# sorted_pairs ('дубом', 1)
# sorted_pairs ('дрібне', 1)
# sorted_pairs ('другої', 1)
# sorted_pairs ('дорозі', 1)
# sorted_pairs ('дорогу', 1)
# sorted_pairs ('довідавсь', 1)
# sorted_pairs ('довге', 1)
# sorted_pairs ('добрий', 1)
# sorted_pairs ('добре', 1)
# sorted_pairs ('добра', 1)
# sorted_pairs ('дитячих', 1)
# sorted_pairs ('дитинстві', 1)
# sorted_pairs ('дивна', 1)
# sorted_pairs ('десь', 1)
# sorted_pairs ('дерлися', 1)
# sorted_pairs ('день', 1)
# sorted_pairs ('дверей', 1)
# sorted_pairs ('дай', 1)
# sorted_pairs ('гучно', 1)
# sorted_pairs ('гукав', 1)
# sorted_pairs ('грушею', 1)
# sorted_pairs ('груш', 1)
# sorted_pairs ('грижа', 1)
# sorted_pairs ('гриби', 1)
# sorted_pairs ('гречаний', 1)
# sorted_pairs ('горілки', 1)
# sorted_pairs ('горіла', 1)
# sorted_pairs ('город', 1)
# sorted_pairs ('горóді', 1)
# sorted_pairs ('гирлига', 1)
# sorted_pairs ('гетьчисто', 1)
# sorted_pairs ('гарну', 1)
# sorted_pairs ('гарно', 1)
# sorted_pairs ('вірили', 1)
# sorted_pairs ('вулицю', 1)
# sorted_pairs ('всяка', 1)
# sorted_pairs ('всередині', 1)
# sorted_pairs ('волосся', 1)
# sorted_pairs ('воза—', 1)
# sorted_pairs ('водилися', 1)
# sorted_pairs ('вміщалися', 1)
# sorted_pairs ('вишень—', 1)
# sorted_pairs ('вишень', 1)
# sorted_pairs ('високий', 1)
# sorted_pairs ('високе', 1)
# sorted_pairs ('випивав', 1)
# sorted_pairs ('вилізає', 1)
# sorted_pairs ('вийти', 1)
# sorted_pairs ('вибухнув', 1)
# sorted_pairs ('взяти', 1)
# sorted_pairs ('вздовж', 1)
# sorted_pairs ('весь', 1)
# sorted_pairs ('весною', 1)
# sorted_pairs ('весело', 1)
# sorted_pairs ('великі', 1)
# sorted_pairs ('велика', 1)
# sorted_pairs ('вгадували', 1)
# sorted_pairs ('вважала', 1)
# sorted_pairs ('білу', 1)
# sorted_pairs ('білої', 1)
# sorted_pairs ('білий', 1)
# sorted_pairs ('біла', 1)
# sorted_pairs ('буряків', 1)
# sorted_pairs ('буйне', 1)
# sorted_pairs ('бузини', 1)
# sorted_pairs ('бубон', 1)
# sorted_pairs ('боячись', 1)
# sorted_pairs ('боялись', 1)
# sorted_pairs ('боявся', 1)
# sorted_pairs ('бороду', 1)
# sorted_pairs ('борзну', 1)
# sorted_pairs ('богу', 1)
# sorted_pairs ('богами', 1)
# sorted_pairs ('бога', 1)
# sorted_pairs ('бесіду', 1)
# sorted_pairs ('бачив', 1)
# sorted_pairs ('батька', 1)
# sorted_pairs ('батурин', 1)
# sorted_pairs ('багато', 1)

# %% [markdown]
# Напишіть функції, що:
# * рохраховує мінімальне та максимальне значення
# * середнє значення послідовності
# * медіану послідовності
# * частоту кожної цифри в послідовності
# * середнє квадратичне відхилення
#
# Послідовність чисел ганеруємо рандомно

# %%
import random

#генеруэмо тисячу чисел в діапазоні від 0 до 100
list_with_random_numbers = [random.randint(0,100) for i in range(1000)]

L = list_with_random_numbers

max = L[0]
min = L[0]
#считаем мин и макс
for i in range(0,len(L)):
    if L[i]<min:
        min=L[i]
    if L[i]>max:
        max=L[i]
print('min =', min)
print('max =', max)

#считаем среднее
from statistics import mean 
list_avg = mean(L)
print("averege =", list_avg)

#считаем медиану
from statistics import median 
list_med = median(L)
print("mediana =", list_med)

#считаем среднеквадратичное
from statistics import stdev
list_stdev = stdev(L)
print("stdev =", list_stdev)

frequency1 = {}
for word in L:
    count = frequency1.get(word,0)
    frequency1[word] = count + 1
     
frequency1_list = frequency1.keys()
print("Частота:", frequency1) 

sorted_pairs1 = {}
for sorted_pairs1 in sorted(frequency1.items(), key=lambda pair: (pair[1], pair[0]), reverse=True):
    print ("Частота з сортуванням:", sorted_pairs1)
# Out:
# min = 0
# max = 100
# averege = 48.771
# mediana = 47.0
# stdev = 28.546934800193284
# Частота: {90: 9, 83: 8, 51: 13, 78: 8, 12: 12, 48: 15, 87: 11, 5: 10, 37: 10, 27: 14, 36: 11, 39: 6, 22: 14, 21: 16, 100: 9, 41: 21, 52: 9, 61: 11, 60: 6, 42: 9, 14: 10, 59: 9, 47: 14, 3: 9, 6: 13, 15: 13, 56: 8, 30: 8, 34: 14, 49: 8, 33: 15, 80: 9, 13: 14, 86: 14, 8: 11, 64: 8, 11: 12, 63: 6, 9: 7, 29: 12, 54: 10, 75: 17, 65: 6, 28: 11, 1: 10, 97: 7, 16: 11, 19: 13, 44: 14, 17: 7, 79: 7, 85: 11, 89: 11, 4: 7, 58: 14, 2: 11, 81: 11, 76: 10, 26: 10, 94: 6, 88: 10, 7: 7, 32: 8, 40: 10, 55: 10, 67: 11, 46: 10, 0: 9, 93: 12, 84: 8, 23: 10, 77: 6, 50: 12, 99: 7, 74: 9, 72: 14, 35: 14, 66: 6, 73: 9, 82: 10, 31: 7, 24: 7, 98: 12, 25: 7, 91: 7, 71: 11, 43: 12, 70: 11, 68: 6, 53: 7, 69: 5, 62: 12, 38: 8, 57: 9, 95: 8, 18: 7, 92: 6, 10: 5, 45: 9, 96: 8, 20: 4}
# Частота з сортуванням: (41, 21)
# Частота з сортуванням: (75, 17)
# Частота з сортуванням: (21, 16)
# Частота з сортуванням: (48, 15)
# Частота з сортуванням: (33, 15)
# Частота з сортуванням: (86, 14)
# Частота з сортуванням: (72, 14)
# Частота з сортуванням: (58, 14)
# Частота з сортуванням: (47, 14)
# Частота з сортуванням: (44, 14)
# Частота з сортуванням: (35, 14)
# Частота з сортуванням: (34, 14)
# Частота з сортуванням: (27, 14)
# Частота з сортуванням: (22, 14)
# Частота з сортуванням: (13, 14)
# Частота з сортуванням: (51, 13)
# Частота з сортуванням: (19, 13)
# Частота з сортуванням: (15, 13)
# Частота з сортуванням: (6, 13)
# Частота з сортуванням: (98, 12)
# Частота з сортуванням: (93, 12)
# Частота з сортуванням: (62, 12)
# Частота з сортуванням: (50, 12)
# Частота з сортуванням: (43, 12)
# Частота з сортуванням: (29, 12)
# Частота з сортуванням: (12, 12)
# Частота з сортуванням: (11, 12)
# Частота з сортуванням: (89, 11)
# Частота з сортуванням: (87, 11)
# Частота з сортуванням: (85, 11)
# Частота з сортуванням: (81, 11)
# Частота з сортуванням: (71, 11)
# Частота з сортуванням: (70, 11)
# Частота з сортуванням: (67, 11)
# Частота з сортуванням: (61, 11)
# Частота з сортуванням: (36, 11)
# Частота з сортуванням: (28, 11)
# Частота з сортуванням: (16, 11)
# Частота з сортуванням: (8, 11)
# Частота з сортуванням: (2, 11)
# Частота з сортуванням: (88, 10)
# Частота з сортуванням: (82, 10)
# Частота з сортуванням: (76, 10)
# Частота з сортуванням: (55, 10)
# Частота з сортуванням: (54, 10)
# Частота з сортуванням: (46, 10)
# Частота з сортуванням: (40, 10)
# Частота з сортуванням: (37, 10)
# Частота з сортуванням: (26, 10)
# Частота з сортуванням: (23, 10)
# Частота з сортуванням: (14, 10)
# Частота з сортуванням: (5, 10)
# Частота з сортуванням: (1, 10)
# Частота з сортуванням: (100, 9)
# Частота з сортуванням: (90, 9)
# Частота з сортуванням: (80, 9)
# Частота з сортуванням: (74, 9)
# Частота з сортуванням: (73, 9)
# Частота з сортуванням: (59, 9)
# Частота з сортуванням: (57, 9)
# Частота з сортуванням: (52, 9)
# Частота з сортуванням: (45, 9)
# Частота з сортуванням: (42, 9)
# Частота з сортуванням: (3, 9)
# Частота з сортуванням: (0, 9)
# Частота з сортуванням: (96, 8)
# Частота з сортуванням: (95, 8)
# Частота з сортуванням: (84, 8)
# Частота з сортуванням: (83, 8)
# Частота з сортуванням: (78, 8)
# Частота з сортуванням: (64, 8)
# Частота з сортуванням: (56, 8)
# Частота з сортуванням: (49, 8)
# Частота з сортуванням: (38, 8)
# Частота з сортуванням: (32, 8)
# Частота з сортуванням: (30, 8)
# Частота з сортуванням: (99, 7)
# Частота з сортуванням: (97, 7)
# Частота з сортуванням: (91, 7)
# Частота з сортуванням: (79, 7)
# Частота з сортуванням: (53, 7)
# Частота з сортуванням: (31, 7)
# Частота з сортуванням: (25, 7)
# Частота з сортуванням: (24, 7)
# Частота з сортуванням: (18, 7)
# Частота з сортуванням: (17, 7)
# Частота з сортуванням: (9, 7)
# Частота з сортуванням: (7, 7)
# Частота з сортуванням: (4, 7)
# Частота з сортуванням: (94, 6)
# Частота з сортуванням: (92, 6)
# Частота з сортуванням: (77, 6)
# Частота з сортуванням: (68, 6)
# Частота з сортуванням: (66, 6)
# Частота з сортуванням: (65, 6)
# Частота з сортуванням: (63, 6)
# Частота з сортуванням: (60, 6)
# Частота з сортуванням: (39, 6)
# Частота з сортуванням: (69, 5)
# Частота з сортуванням: (10, 5)
# Частота з сортуванням: (20, 4)
